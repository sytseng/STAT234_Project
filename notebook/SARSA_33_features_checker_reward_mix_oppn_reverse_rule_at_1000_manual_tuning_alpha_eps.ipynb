# %%
from autograd import numpy as np
from autograd import grad
from autograd.misc.optimizers import adam
import matplotlib.pyplot as plt
import pickle

from game import *
from agents import *
from checkers import *

# %%
n_features = 34
feature_func = checkers_features_augmented

reward_function = checkers_reward

max_moves = 500
np.random.seed(12)
initial_weights = np.random.normal(size=n_features)

ab1 = AlphaBetaAgent(1)
ab2 = AlphaBetaAgent(2)
ab3 = AlphaBetaAgent(3)
rand_agent = RandomAgent()

quiet = True
n_train_games = 1000
n_decay = 10
n_games_test = 10
test_frequency = 10
max_random_start_depth_train = 3
max_random_start_depth_test = 3
gamma = 0.7
initial_alpha = 0.001
initial_epsilon = 0.35

first_agent = SarsaLearningAgent(feature_func, n_features, reward_function = reward_function, alpha=initial_alpha, gamma=gamma, epsilon=initial_epsilon, is_learning_agent=True, weights=initial_weights)
second_agent_list = [ab1, ab2, ab3, rand_agent]
all_results = []
all_draws = []
all_oppn_idx = []
all_weights = []
all_rewards = []
all_num = []
test_results_rand = []
test_results_1 = []
test_results_2 = []
test_results_3 = []
test_draws_rand = []
test_draws_1 = []
test_draws_2 = []
test_draws_3 = []

# pre-training test
this_test_results_rand = []
this_test_results_1 = []
this_test_results_2 = []
this_test_results_3 = []

this_test_draws_rand = []
this_test_draws_1 = []
this_test_draws_2 = []
this_test_draws_3 = []

for n in range(n_games_test):
    test_agent = SarsaLearningAgent(feature_func, n_features, reward_function = reward_function, alpha=0., gamma=gamma, epsilon=initial_epsilon, is_learning_agent=False, weights=initial_weights)
    # play against ab1
    first_agent_turn = bool(np.random.binomial(1,0.5))
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(test_agent, ab1, first_agent_turn, quiet=quiet)

    # random start
    random_start_spots = game.game_state.board.spots
    for _ in range(np.random.choice(max_random_start_depth_test)*2):
        possible_moves = game.game_state.board.get_possible_next_moves()
        next_move = possible_moves[np.random.choice(len(possible_moves),size=1)[0]]
        game.game_state.board.make_move(next_move, switch_player_turn=True)
        random_start_spots = game.game_state.board.spots

    num_moves, game_state = game.run()
    this_test_results_1.append(game_state.is_first_agent_win())
    this_test_draws_1.append(game_state.max_moves_done)

    # play against ab2
    first_agent_turn = bool(np.random.binomial(1,0.5))
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(test_agent, ab2, first_agent_turn, quiet=quiet)
    game.game_state.board.spots = random_start_spots # set start board position to the same random start
    num_moves, game_state = game.run()
    this_test_results_2.append(game_state.is_first_agent_win())
    this_test_draws_2.append(game_state.max_moves_done)

    # play against ab3
    first_agent_turn = bool(np.random.binomial(1,0.5))
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(test_agent, ab3, first_agent_turn, quiet=quiet)
    game.game_state.board.spots = random_start_spots # set start board position to the same random start
    num_moves, game_state = game.run()
    this_test_results_3.append(game_state.is_first_agent_win())
    this_test_draws_3.append(game_state.max_moves_done)

    # play against random agent
    first_agent_turn = bool(np.random.binomial(1,0.5))
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(test_agent, rand_agent, first_agent_turn, quiet=quiet)
    game.game_state.board.spots = random_start_spots # set start board position to the same random start
    num_moves, game_state = game.run()
    this_test_results_rand.append(game_state.is_first_agent_win())
    this_test_draws_rand.append(game_state.max_moves_done)

test_results_1.append(np.mean(np.array(this_test_results_1)))
test_results_2.append(np.mean(np.array(this_test_results_2)))
test_results_3.append(np.mean(np.array(this_test_results_3)))
test_results_rand.append(np.mean(np.array(this_test_results_rand)))

test_draws_1.append(np.mean(np.array(this_test_draws_1)))
test_draws_2.append(np.mean(np.array(this_test_draws_2)))
test_draws_3.append(np.mean(np.array(this_test_draws_3)))
test_draws_rand.append(np.mean(np.array(this_test_draws_rand)))


# training 
for n in range(n_train_games):    
    # change alpha and epsilon after n_decay games
    if n%n_decay == n_decay-1:
        first_agent.alpha = max([0.95*first_agent.alpha, 1e-4])
        first_agent.epsilon = max([0.95*first_agent.epsilon, 0.05])
        print(n, 'Fraction of wins = ', np.mean(all_results[-n_decay:]), 'Fraction of draws = ', np.mean(all_draws[-n_decay:]))
        print(n ,'alpha = ',first_agent.alpha, 'epsilon = ',first_agent.epsilon)
    
    if n%50 == 0: print(n)
    # train against randomly selected agent
    first_agent_turn = bool(np.random.binomial(1,0.5))
    
    second_agent_idx = np.random.choice(len(second_agent_list))  
    all_oppn_idx.append(second_agent_idx)
    second_agent = second_agent_list[second_agent_idx]
    
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(first_agent, second_agent, first_agent_turn, quiet=quiet)    
    
    # random start
    for _ in range(np.random.choice(max_random_start_depth_train)*2):
        possible_moves = game.game_state.board.get_possible_next_moves()
        next_move = possible_moves[np.random.choice(len(possible_moves),size=1)[0]]
        game.game_state.board.make_move(next_move, switch_player_turn=True)
        
    num_moves, game_state = game.run()
    
    all_num.append(num_moves)
    all_rewards.append(first_agent.episode_rewards)
    all_results.append(game_state.is_first_agent_win())
    all_draws.append((game_state.max_moves_done))
    all_weights.append(first_agent.weights.copy())
        
    if n%test_frequency == test_frequency-1:
        
        this_test_results_rand = []
        this_test_results_1 = []
        this_test_results_2 = []
        this_test_results_3 = []
        
        this_test_draws_rand = []
        this_test_draws_1 = []
        this_test_draws_2 = []
        this_test_draws_3 = []
        
        for n in range(n_games_test):
            current_epislon = first_agent.epsilon
            test_agent = SarsaLearningAgent(feature_func, n_features, reward_function = reward_function, alpha=0., gamma=gamma, epsilon=current_epislon, is_learning_agent=False, weights=all_weights[-1])
            # play against ab1
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab1, first_agent_turn, quiet=quiet)
            
            # random start
            random_start_spots = game.game_state.board.spots
            for _ in range(np.random.choice(max_random_start_depth_test)*2):
                possible_moves = game.game_state.board.get_possible_next_moves()
                next_move = possible_moves[np.random.choice(len(possible_moves),size=1)[0]]
                game.game_state.board.make_move(next_move, switch_player_turn=True)
                random_start_spots = game.game_state.board.spots
        
            num_moves, game_state = game.run()
            this_test_results_1.append(game_state.is_first_agent_win())
            this_test_draws_1.append(game_state.max_moves_done)
            
            # play against ab2
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab2, first_agent_turn, quiet=quiet)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_2.append(game_state.is_first_agent_win())
            this_test_draws_2.append(game_state.max_moves_done)
            
            # play against ab3
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab3, first_agent_turn, quiet=quiet)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_3.append(game_state.is_first_agent_win())
            this_test_draws_3.append(game_state.max_moves_done)
            
            # play against random agent
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, rand_agent, first_agent_turn, quiet=quiet)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_rand.append(game_state.is_first_agent_win())
            this_test_draws_rand.append(game_state.max_moves_done)
            
        test_results_1.append(np.mean(np.array(this_test_results_1)))
        test_results_2.append(np.mean(np.array(this_test_results_2)))
        test_results_3.append(np.mean(np.array(this_test_results_3)))
        test_results_rand.append(np.mean(np.array(this_test_results_rand)))
        
        test_draws_1.append(np.mean(np.array(this_test_draws_1)))
        test_draws_2.append(np.mean(np.array(this_test_draws_2)))
        test_draws_3.append(np.mean(np.array(this_test_draws_3)))
        test_draws_rand.append(np.mean(np.array(this_test_draws_rand)))
        
        print('wins = ',test_results_1[-1],test_results_2[-1],test_results_3[-1],test_results_rand[-1])    
        print('draws = ',test_draws_1[-1],test_draws_2[-1],test_draws_3[-1],test_draws_rand[-1])
# Out:
# 0
# 9 Fraction of wins =  0.3333333333333333 Fraction of draws =  0.0
# 9 alpha =  0.00095 epsilon =  0.33249999999999996
# wins =  0.3 0.0 0.0 0.9
# draws =  0.4 0.3 0.7 0.0
# 19 Fraction of wins =  0.3 Fraction of draws =  0.0
# 19 alpha =  0.0009025 epsilon =  0.31587499999999996
# wins =  0.3 0.2 0.1 0.9
# draws =  0.7 0.5 0.5 0.1
# 29 Fraction of wins =  0.4 Fraction of draws =  0.1
# 29 alpha =  0.000857375 epsilon =  0.30008124999999997
# wins =  0.6 0.1 0.0 1.0
# draws =  0.4 0.5 0.3 0.0
# 39 Fraction of wins =  0.4 Fraction of draws =  0.0
# 39 alpha =  0.0008145062499999999 epsilon =  0.28507718749999994
# wins =  0.8 0.1 0.1 1.0
# draws =  0.2 0.5 0.2 0.0
# 49 Fraction of wins =  0.5 Fraction of draws =  0.0
# 49 alpha =  0.0007737809374999998 epsilon =  0.27082332812499993
# wins =  1.0 0.0 0.0 1.0
# draws =  0.0 0.9 0.6 0.0
# 50
# 59 Fraction of wins =  0.6 Fraction of draws =  0.0
# 59 alpha =  0.0007350918906249997 epsilon =  0.2572821617187499
# wins =  0.8 0.2 0.0 1.0
# draws =  0.2 0.5 0.3 0.0
# 69 Fraction of wins =  0.3 Fraction of draws =  0.1
# 69 alpha =  0.0006983372960937497 epsilon =  0.24441805363281238
# wins =  1.0 0.1 0.1 1.0
# draws =  0.0 0.5 0.3 0.0
# 79 Fraction of wins =  0.5 Fraction of draws =  0.0
# 79 alpha =  0.0006634204312890621 epsilon =  0.23219715095117174
# wins =  0.9 0.3 0.0 1.0
# draws =  0.1 0.5 0.2 0.0
# 89 Fraction of wins =  0.7 Fraction of draws =  0.0
# 89 alpha =  0.000630249409724609 epsilon =  0.22058729340361313
# wins =  0.7 0.2 0.1 1.0
# draws =  0.3 0.6 0.4 0.0
# 99 Fraction of wins =  0.7 Fraction of draws =  0.1
# 99 alpha =  0.0005987369392383785 epsilon =  0.20955792873343246
# wins =  1.0 0.2 0.1 1.0
# draws =  0.0 0.6 0.7 0.0
# 100
# 109 Fraction of wins =  0.3 Fraction of draws =  0.0
# 109 alpha =  0.0005688000922764595 epsilon =  0.19908003229676083
# wins =  0.3 0.1 0.0 0.6
# draws =  0.3 0.4 0.1 0.0
# 119 Fraction of wins =  0.3 Fraction of draws =  0.0
# 119 alpha =  0.0005403600876626365 epsilon =  0.18912603068192277
# wins =  0.9 0.2 0.0 1.0
# draws =  0.1 0.7 0.7 0.0
# 129 Fraction of wins =  0.2 Fraction of draws =  0.0
# 129 alpha =  0.0005133420832795047 epsilon =  0.1796697291478266
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.5 0.3 0.0
# 139 Fraction of wins =  0.5 Fraction of draws =  0.1
# 139 alpha =  0.00048767497911552944 epsilon =  0.17068624269043528
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.5 0.7 0.0
# 149 Fraction of wins =  0.5 Fraction of draws =  0.0
# 149 alpha =  0.00046329123015975297 epsilon =  0.1621519305559135
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.9 0.4 0.0
# 150
# 159 Fraction of wins =  0.3 Fraction of draws =  0.1
# 159 alpha =  0.0004401266686517653 epsilon =  0.15404433402811782
# wins =  0.6 0.3 0.0 1.0
# draws =  0.4 0.4 0.2 0.0
# 169 Fraction of wins =  0.6 Fraction of draws =  0.0
# 169 alpha =  0.00041812033521917703 epsilon =  0.14634211732671193
# wins =  0.4 0.0 0.0 1.0
# draws =  0.5 0.4 0.4 0.0
# 179 Fraction of wins =  0.5 Fraction of draws =  0.1
# 179 alpha =  0.00039721431845821814 epsilon =  0.13902501146037632
# wins =  0.8 0.0 0.0 1.0
# draws =  0.0 0.4 0.0 0.0
# 189 Fraction of wins =  0.3 Fraction of draws =  0.0
# 189 alpha =  0.0003773536025353072 epsilon =  0.1320737608873575
# wins =  0.4 0.0 0.0 0.3
# draws =  0.2 0.0 0.0 0.0
# 199 Fraction of wins =  0.7 Fraction of draws =  0.0
# 199 alpha =  0.0003584859224085418 epsilon =  0.1254700728429896
# wins =  0.4 0.0 0.0 0.9
# draws =  0.4 0.1 0.1 0.0
# 200
# 209 Fraction of wins =  0.3 Fraction of draws =  0.0
# 209 alpha =  0.0003405616262881147 epsilon =  0.11919656920084012
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.8 0.6 0.0
# 219 Fraction of wins =  0.4 Fraction of draws =  0.2
# 219 alpha =  0.00032353354497370894 epsilon =  0.11323674074079812
# wins =  0.6 0.1 0.0 1.0
# draws =  0.4 0.5 0.4 0.0
# 229 Fraction of wins =  0.5 Fraction of draws =  0.0
# 229 alpha =  0.00030735686772502346 epsilon =  0.1075749037037582
# wins =  0.9 0.2 0.0 1.0
# draws =  0.0 0.7 0.5 0.0
# 239 Fraction of wins =  0.3 Fraction of draws =  0.1
# 239 alpha =  0.00029198902433877225 epsilon =  0.1021961585185703
# wins =  0.6 0.2 0.0 1.0
# draws =  0.2 0.8 0.4 0.0
# 249 Fraction of wins =  0.5 Fraction of draws =  0.0
# 249 alpha =  0.00027738957312183364 epsilon =  0.09708635059264177
# wins =  0.8 0.0 0.0 1.0
# draws =  0.1 0.6 0.2 0.0
# 250
# 259 Fraction of wins =  0.5 Fraction of draws =  0.0
# 259 alpha =  0.0002635200944657419 epsilon =  0.09223203306300967
# wins =  0.9 0.0 0.1 1.0
# draws =  0.0 0.9 0.2 0.0
# 269 Fraction of wins =  0.8 Fraction of draws =  0.0
# 269 alpha =  0.0002503440897424548 epsilon =  0.08762043140985919
# wins =  0.4 0.0 0.0 0.7
# draws =  0.6 0.1 0.6 0.0
# 279 Fraction of wins =  0.8 Fraction of draws =  0.0
# 279 alpha =  0.00023782688525533205 epsilon =  0.08323940983936623
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 1.0 0.7 0.0
# 289 Fraction of wins =  0.2 Fraction of draws =  0.2
# 289 alpha =  0.00022593554099256544 epsilon =  0.07907743934739792
# wins =  0.8 0.0 0.1 1.0
# draws =  0.2 1.0 0.7 0.0
# 299 Fraction of wins =  0.8 Fraction of draws =  0.1
# 299 alpha =  0.00021463876394293716 epsilon =  0.07512356738002801
# wins =  0.6 0.0 0.0 1.0
# draws =  0.4 1.0 0.3 0.0
# 300
# 309 Fraction of wins =  0.5 Fraction of draws =  0.0
# 309 alpha =  0.0002039068257457903 epsilon =  0.07136738901102661
# wins =  0.5 0.0 0.0 1.0
# draws =  0.5 0.9 0.4 0.0
# 319 Fraction of wins =  0.5 Fraction of draws =  0.1
# 319 alpha =  0.00019371148445850077 epsilon =  0.06779901956047528
# wins =  0.7 0.1 0.0 1.0
# draws =  0.3 0.7 0.4 0.0
# 329 Fraction of wins =  0.5 Fraction of draws =  0.0
# 329 alpha =  0.00018402591023557573 epsilon =  0.06440906858245152
# wins =  0.6 0.0 0.0 1.0
# draws =  0.4 0.8 0.3 0.0
# 339 Fraction of wins =  0.4 Fraction of draws =  0.2
# 339 alpha =  0.00017482461472379692 epsilon =  0.06118861515332894
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.9 0.3 0.0
# 349 Fraction of wins =  0.5 Fraction of draws =  0.0
# 349 alpha =  0.00016608338398760707 epsilon =  0.05812918439566249
# wins =  0.5 0.0 0.0 1.0
# draws =  0.5 0.8 0.3 0.0
# 350
# 359 Fraction of wins =  0.3 Fraction of draws =  0.1
# 359 alpha =  0.0001577792147882267 epsilon =  0.05522272517587936
# wins =  0.4 0.1 0.0 1.0
# draws =  0.6 0.7 0.5 0.0
# 369 Fraction of wins =  0.8 Fraction of draws =  0.1
# 369 alpha =  0.00014989025404881537 epsilon =  0.05246158891708539
# wins =  0.6 0.1 0.0 1.0
# draws =  0.4 0.4 0.5 0.0
# 379 Fraction of wins =  0.2 Fraction of draws =  0.3
# 379 alpha =  0.00014239574134637458 epsilon =  0.05
# wins =  0.7 0.1 0.1 1.0
# draws =  0.3 0.5 0.3 0.0
# 389 Fraction of wins =  0.3 Fraction of draws =  0.1
# 389 alpha =  0.00013527595427905584 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.7 0.4 0.0
# 399 Fraction of wins =  0.3 Fraction of draws =  0.2
# 399 alpha =  0.00012851215656510304 epsilon =  0.05
# wins =  1.0 0.0 0.1 1.0
# draws =  0.0 0.9 0.7 0.0
# 400
# 409 Fraction of wins =  0.4 Fraction of draws =  0.1
# 409 alpha =  0.00012208654873684788 epsilon =  0.05
# wins =  0.5 0.0 0.0 1.0
# draws =  0.5 1.0 0.7 0.0
# 419 Fraction of wins =  0.3 Fraction of draws =  0.2
# 419 alpha =  0.00011598222130000548 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.1 0.8 0.7 0.0
# 429 Fraction of wins =  0.4 Fraction of draws =  0.2
# 429 alpha =  0.00011018311023500519 epsilon =  0.05
# wins =  0.6 0.1 0.0 1.0
# draws =  0.3 0.7 0.4 0.0
# 439 Fraction of wins =  0.4 Fraction of draws =  0.0
# 439 alpha =  0.00010467395472325493 epsilon =  0.05
# wins =  0.7 0.1 0.0 1.0
# draws =  0.3 0.6 0.2 0.0
# 449 Fraction of wins =  0.6 Fraction of draws =  0.1
# 449 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.1 1.0
# draws =  0.2 1.0 0.2 0.0
# 450
# 459 Fraction of wins =  0.6 Fraction of draws =  0.3
# 459 alpha =  0.0001 epsilon =  0.05
# wins =  0.6 0.0 0.0 1.0
# draws =  0.2 0.7 0.4 0.0
# 469 Fraction of wins =  0.4 Fraction of draws =  0.1
# 469 alpha =  0.0001 epsilon =  0.05
# wins =  0.6 0.0 0.0 1.0
# draws =  0.4 0.5 0.3 0.0
# 479 Fraction of wins =  0.4 Fraction of draws =  0.1
# 479 alpha =  0.0001 epsilon =  0.05
# wins =  0.6 0.1 0.0 1.0
# draws =  0.4 0.4 0.3 0.0
# 489 Fraction of wins =  0.2 Fraction of draws =  0.4
# 489 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.3 0.4 0.0
# 499 Fraction of wins =  0.5 Fraction of draws =  0.1
# 499 alpha =  0.0001 epsilon =  0.05
# wins =  0.6 0.0 0.0 1.0
# draws =  0.3 0.7 0.5 0.0
# 500
# 509 Fraction of wins =  0.3 Fraction of draws =  0.3
# 509 alpha =  0.0001 epsilon =  0.05
# wins =  0.6 0.0 0.0 1.0
# draws =  0.2 0.7 0.8 0.0
# 519 Fraction of wins =  0.5 Fraction of draws =  0.0
# 519 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.3 1.0 0.8 0.0
# 529 Fraction of wins =  0.5 Fraction of draws =  0.3
# 529 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.0 0.5 0.4 0.0
# 539 Fraction of wins =  0.3 Fraction of draws =  0.3
# 539 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.8 0.9 0.0
# 549 Fraction of wins =  0.4 Fraction of draws =  0.3
# 549 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.1 0.0 1.0
# draws =  0.1 0.7 0.7 0.0
# 550
# 559 Fraction of wins =  0.3 Fraction of draws =  0.3
# 559 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.7 0.7 0.0
# 569 Fraction of wins =  0.7 Fraction of draws =  0.0
# 569 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 1.0 0.5 0.0
# 579 Fraction of wins =  0.2 Fraction of draws =  0.2
# 579 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.2 0.0 1.0
# draws =  0.3 0.7 0.4 0.0
# 589 Fraction of wins =  0.3 Fraction of draws =  0.3
# 589 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.1 1.0
# draws =  0.1 0.4 0.4 0.0
# 599 Fraction of wins =  0.5 Fraction of draws =  0.1
# 599 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.7 0.6 0.0
# 600
# 609 Fraction of wins =  0.6 Fraction of draws =  0.1
# 609 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.6 0.7 0.0
# 619 Fraction of wins =  0.4 Fraction of draws =  0.3
# 619 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.4 0.6 0.0
# 629 Fraction of wins =  0.4 Fraction of draws =  0.1
# 629 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.1 0.0 1.0
# draws =  0.0 0.3 0.7 0.0
# 639 Fraction of wins =  0.6 Fraction of draws =  0.2
# 639 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.0 0.0 1.0
# draws =  0.0 0.9 0.6 0.0
# 649 Fraction of wins =  0.6 Fraction of draws =  0.1
# 649 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.2 0.4 0.9 0.0
# 650
# 659 Fraction of wins =  0.5 Fraction of draws =  0.0
# 659 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.4 1.0
# draws =  0.3 0.8 0.2 0.0
# 669 Fraction of wins =  0.6 Fraction of draws =  0.2
# 669 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.2 0.0 1.0
# draws =  0.2 0.6 0.5 0.0
# 679 Fraction of wins =  0.5 Fraction of draws =  0.2
# 679 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.6 0.5 0.0
# 689 Fraction of wins =  0.6 Fraction of draws =  0.3
# 689 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.1 0.9
# draws =  0.1 0.5 0.3 0.0
# 699 Fraction of wins =  0.4 Fraction of draws =  0.2
# 699 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.1 1.0
# draws =  0.3 0.4 0.3 0.0
# 700
# 709 Fraction of wins =  0.6 Fraction of draws =  0.1
# 709 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.1 0.1 1.0
# draws =  0.0 0.6 0.2 0.0
# 719 Fraction of wins =  0.5 Fraction of draws =  0.1
# 719 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.1 0.0 1.0
# draws =  0.1 0.7 0.5 0.0
# 729 Fraction of wins =  0.4 Fraction of draws =  0.1
# 729 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.3 0.7 0.1 0.0
# 739 Fraction of wins =  0.5 Fraction of draws =  0.3
# 739 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.1 0.6 0.5 0.0
# 749 Fraction of wins =  0.5 Fraction of draws =  0.1
# 749 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 1.0 0.3 0.0
# 750
# 759 Fraction of wins =  0.5 Fraction of draws =  0.3
# 759 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.1 0.0 1.0
# draws =  0.0 0.5 0.5 0.0
# 769 Fraction of wins =  0.5 Fraction of draws =  0.1
# 769 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.3 0.8 0.5 0.0
# 779 Fraction of wins =  0.3 Fraction of draws =  0.3
# 779 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.4 0.3 0.0
# 789 Fraction of wins =  0.7 Fraction of draws =  0.0
# 789 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.2 0.6 0.4 0.0
# 799 Fraction of wins =  0.3 Fraction of draws =  0.2
# 799 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.1 0.3 1.0
# draws =  0.3 0.8 0.2 0.0
# 800
# 809 Fraction of wins =  0.7 Fraction of draws =  0.3
# 809 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.1 1.0
# draws =  0.2 0.8 0.5 0.0
# 819 Fraction of wins =  0.4 Fraction of draws =  0.1
# 819 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.3 0.5 0.3 0.0
# 829 Fraction of wins =  0.5 Fraction of draws =  0.1
# 829 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.1 0.9
# draws =  0.2 1.0 0.4 0.0
# 839 Fraction of wins =  0.6 Fraction of draws =  0.1
# 839 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.1 0.0 0.9
# draws =  0.1 0.4 0.3 0.1
# 849 Fraction of wins =  0.9 Fraction of draws =  0.1
# 849 alpha =  0.0001 epsilon =  0.05
# wins =  0.4 0.0 0.0 1.0
# draws =  0.5 0.7 0.5 0.0
# 850
# 859 Fraction of wins =  0.6 Fraction of draws =  0.0
# 859 alpha =  0.0001 epsilon =  0.05
# wins =  0.5 0.1 0.0 1.0
# draws =  0.5 0.6 0.8 0.0
# 869 Fraction of wins =  0.4 Fraction of draws =  0.3
# 869 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.6 0.9 0.0
# 879 Fraction of wins =  0.5 Fraction of draws =  0.0
# 879 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.1 1.0
# draws =  0.0 0.6 0.4 0.0
# 889 Fraction of wins =  0.5 Fraction of draws =  0.1
# 889 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.1 0.0 1.0
# draws =  0.3 0.2 0.2 0.0
# 899 Fraction of wins =  0.5 Fraction of draws =  0.2
# 899 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.0 0.0 1.0
# draws =  0.1 0.6 0.4 0.0
# 900
# 909 Fraction of wins =  0.6 Fraction of draws =  0.1
# 909 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.1 0.0 1.0
# draws =  0.2 0.6 0.6 0.0
# 919 Fraction of wins =  0.7 Fraction of draws =  0.1
# 919 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.2 0.0 1.0
# draws =  0.0 0.6 0.5 0.0
# 929 Fraction of wins =  0.5 Fraction of draws =  0.1
# 929 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.8 0.8 0.0
# 939 Fraction of wins =  0.4 Fraction of draws =  0.1
# 939 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.0 0.6 0.4 0.0
# 949 Fraction of wins =  0.5 Fraction of draws =  0.1
# 949 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.2 0.7 0.3 0.0
# 950
# 959 Fraction of wins =  0.6 Fraction of draws =  0.0
# 959 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.5 0.5 0.0
# 969 Fraction of wins =  0.3 Fraction of draws =  0.4
# 969 alpha =  0.0001 epsilon =  0.05
# wins =  0.5 0.1 0.0 1.0
# draws =  0.4 0.5 0.7 0.0
# 979 Fraction of wins =  0.3 Fraction of draws =  0.4
# 979 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.1 0.0 1.0
# draws =  0.2 0.6 0.4 0.0
# 989 Fraction of wins =  0.7 Fraction of draws =  0.1
# 989 alpha =  0.0001 epsilon =  0.05
# wins =  0.7 0.0 0.0 1.0
# draws =  0.3 0.6 0.8 0.0
# 999 Fraction of wins =  0.6 Fraction of draws =  0.2
# 999 alpha =  0.0001 epsilon =  0.05
# wins =  0.8 0.0 0.0 1.0
# draws =  0.1 0.9 0.4 0.0

# %%
def reverse_checkers_reward(state, action, next_state):

    if next_state.is_game_over():
        # infer turn from current state, because at the end same state is used by both agents
        if state.is_first_agent_turn():
            return WIN_REWARD if next_state.is_first_agent_win() else LOSE_REWARD
        else:
            return WIN_REWARD if next_state.is_second_agent_win() else LOSE_REWARD

    agent_ind = 0 if state.is_first_agent_turn() else 1
    oppn_ind = 1 if state.is_first_agent_turn() else 0

    num_pieces_list = state.get_pieces_and_kings()

    agent_pawns = num_pieces_list[agent_ind]
    agent_kings = num_pieces_list[agent_ind + 2]

    oppn_pawns = num_pieces_list[oppn_ind]
    oppn_kings = num_pieces_list[oppn_ind + 2]

    num_pieces_list_n = next_state.get_pieces_and_kings()

    agent_pawns_n = num_pieces_list_n[agent_ind]
    agent_kings_n = num_pieces_list_n[agent_ind + 2]

    oppn_pawns_n = num_pieces_list_n[oppn_ind]
    oppn_kings_n = num_pieces_list_n[oppn_ind + 2]

    r_1 = agent_pawns - agent_pawns_n
    r_2 = agent_kings - agent_kings_n
    r_3 = oppn_pawns - oppn_pawns_n
    r_4 = oppn_kings - oppn_kings_n

    reward = -(r_3 * 0.2 + r_4 * 0.3 + r_1 * (-0.4) + r_2 * (-0.5))

    if reward == 0:
        reward = LIVING_REWARD

    return reward

# %%
# reverse rule
    # change opponent reward
    # change agent reward
    # change rule to reverse
    # resume learing rate and epsilon
    
    
# generate opponents using opposite reward
ab1_r = AlphaBetaAgent(1, reward_direction=-1)
ab2_r = AlphaBetaAgent(2, reward_direction=-1)
ab3_r = AlphaBetaAgent(3, reward_direction=-1)        
second_agent_list_post_reversal = [ab1_r, ab2_r, ab3_r, rand_agent]

n_train_games_post_reversal = 1000

# set reverse rule (in ClassicGameRules.new_game)
reverse = True

# RL agent: takes reverse reward, use last weight, resumeinital alpha and epsilon
first_agent = SarsaLearningAgent(feature_func, n_features, reward_function = reverse_checkers_reward, 
                                 alpha=initial_alpha, gamma=gamma, epsilon=initial_epsilon, 
                                 is_learning_agent=True, weights=all_weights[n_train_games-1])

for n in range(n_train_games_post_reversal):    
    # change alpha and epsilon after n_decay games
    if n%n_decay == n_decay-1:
        first_agent.alpha = max([0.95*first_agent.alpha, 1e-4])
        first_agent.epsilon = max([0.95*first_agent.epsilon, 0.05])
        print(n, 'Fraction of wins = ', np.mean(all_results[-n_decay:]), 'Fraction of draws = ', np.mean(all_draws[-n_decay:]))
        print(n ,'alpha = ',first_agent.alpha, 'epsilon = ',first_agent.epsilon)
    
    if n%50 == 0: print(n)
    # train against randomly selected agent
    first_agent_turn = bool(np.random.binomial(1,0.5))
    
    second_agent_idx = np.random.choice(len(second_agent_list_post_reversal))  
    all_oppn_idx.append(second_agent_idx)
    second_agent = second_agent_list_post_reversal[second_agent_idx]
    
    rules = ClassicGameRules(max_moves=max_moves)
    game = rules.new_game(first_agent, second_agent, first_agent_turn, quiet=quiet, reverse=reverse)    
    
    # random start
    for _ in range(np.random.choice(max_random_start_depth_train)*2):
        possible_moves = game.game_state.board.get_possible_next_moves()
        next_move = possible_moves[np.random.choice(len(possible_moves),size=1)[0]]
        game.game_state.board.make_move(next_move, switch_player_turn=True)
        
    num_moves, game_state = game.run()
    
    all_num.append(num_moves)
    all_rewards.append(first_agent.episode_rewards)
    all_results.append(game_state.is_first_agent_win())
    all_draws.append((game_state.max_moves_done))
    all_weights.append(first_agent.weights.copy())
        
    if n%test_frequency == test_frequency-1:
        
        this_test_results_rand = []
        this_test_results_1 = []
        this_test_results_2 = []
        this_test_results_3 = []
        
        this_test_draws_rand = []
        this_test_draws_1 = []
        this_test_draws_2 = []
        this_test_draws_3 = []
        
        for n in range(n_games_test):
            current_epislon = first_agent.epsilon
            test_agent = SarsaLearningAgent(feature_func, n_features, reward_function = reverse_checkers_reward, 
                                            alpha=0., gamma=gamma, epsilon=current_epislon, 
                                            is_learning_agent=False, weights=all_weights[-1])
            # play against ab1_r
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab1_r, first_agent_turn, quiet=quiet, reverse=reverse)
            
            # random start
            random_start_spots = game.game_state.board.spots
            for _ in range(np.random.choice(max_random_start_depth_test)*2):
                possible_moves = game.game_state.board.get_possible_next_moves()
                next_move = possible_moves[np.random.choice(len(possible_moves),size=1)[0]]
                game.game_state.board.make_move(next_move, switch_player_turn=reverse)
                random_start_spots = game.game_state.board.spots
        
            num_moves, game_state = game.run()
            this_test_results_1.append(game_state.is_first_agent_win())
            this_test_draws_1.append(game_state.max_moves_done)
            
            # play against ab2_r
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab2_r, first_agent_turn, quiet=quiet, reverse=reverse)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_2.append(game_state.is_first_agent_win())
            this_test_draws_2.append(game_state.max_moves_done)
            
            # play against ab3_r
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, ab3_r, first_agent_turn, quiet=quiet, reverse=reverse)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_3.append(game_state.is_first_agent_win())
            this_test_draws_3.append(game_state.max_moves_done)
            
            # play against random agent
            first_agent_turn = bool(np.random.binomial(1,0.5))
            rules = ClassicGameRules(max_moves=max_moves)
            game = rules.new_game(test_agent, rand_agent, first_agent_turn, quiet=quiet, reverse=True)
            game.game_state.board.spots = random_start_spots # set start board position to the same random start
            num_moves, game_state = game.run()
            this_test_results_rand.append(game_state.is_first_agent_win())
            this_test_draws_rand.append(game_state.max_moves_done)
            
        test_results_1.append(np.mean(np.array(this_test_results_1)))
        test_results_2.append(np.mean(np.array(this_test_results_2)))
        test_results_3.append(np.mean(np.array(this_test_results_3)))
        test_results_rand.append(np.mean(np.array(this_test_results_rand)))
        
        test_draws_1.append(np.mean(np.array(this_test_draws_1)))
        test_draws_2.append(np.mean(np.array(this_test_draws_2)))
        test_draws_3.append(np.mean(np.array(this_test_draws_3)))
        test_draws_rand.append(np.mean(np.array(this_test_draws_rand)))
        
        print('wins = ',test_results_1[-1],test_results_2[-1],test_results_3[-1],test_results_rand[-1])    
        print('draws = ',test_draws_1[-1],test_draws_2[-1],test_draws_3[-1],test_draws_rand[-1])
# Out:
# 0
# 9 Fraction of wins =  0.0 Fraction of draws =  0.1
# 9 alpha =  0.00095 epsilon =  0.33249999999999996
# wins =  0.1 0.0 0.0 0.1
# draws =  0.1 0.3 0.2 0.0
# 19 Fraction of wins =  0.0 Fraction of draws =  0.0
# 19 alpha =  0.0009025 epsilon =  0.31587499999999996
# wins =  0.1 0.0 0.0 0.0
# draws =  0.4 0.2 0.3 0.0
# 29 Fraction of wins =  0.0 Fraction of draws =  0.0
# 29 alpha =  0.000857375 epsilon =  0.30008124999999997
# wins =  0.1 0.0 0.0 0.5
# draws =  0.5 0.4 0.0 0.0
# 39 Fraction of wins =  0.3 Fraction of draws =  0.0
# 39 alpha =  0.0008145062499999999 epsilon =  0.28507718749999994
# wins =  0.4 0.0 0.0 0.7
# draws =  0.6 0.5 0.4 0.0
# 49 Fraction of wins =  0.1 Fraction of draws =  0.0
# 49 alpha =  0.0007737809374999998 epsilon =  0.27082332812499993
# wins =  0.5 0.0 0.0 0.9
# draws =  0.3 0.3 0.3 0.0
# 50
# 59 Fraction of wins =  0.3 Fraction of draws =  0.1
# 59 alpha =  0.0007350918906249997 epsilon =  0.2572821617187499
# wins =  0.2 0.1 0.0 0.8
# draws =  0.3 0.3 0.2 0.0
# 69 Fraction of wins =  0.2 Fraction of draws =  0.2
# 69 alpha =  0.0006983372960937497 epsilon =  0.24441805363281238
# wins =  0.0 0.0 0.0 0.2
# draws =  0.1 0.1 0.3 0.0
# 79 Fraction of wins =  0.3 Fraction of draws =  0.0
# 79 alpha =  0.0006634204312890621 epsilon =  0.23219715095117174
# wins =  0.8 0.0 0.0 0.9
# draws =  0.2 0.7 0.2 0.0
# 89 Fraction of wins =  0.1 Fraction of draws =  0.1
# 89 alpha =  0.000630249409724609 epsilon =  0.22058729340361313
# wins =  0.9 0.1 0.1 0.9
# draws =  0.1 0.5 0.1 0.0
# 99 Fraction of wins =  0.6 Fraction of draws =  0.2
# 99 alpha =  0.0005987369392383785 epsilon =  0.20955792873343246
# wins =  0.9 0.5 0.0 0.9
# draws =  0.1 0.4 0.1 0.0
# 100
# 109 Fraction of wins =  0.6 Fraction of draws =  0.0
# 109 alpha =  0.0005688000922764595 epsilon =  0.19908003229676083
# wins =  0.8 0.3 0.0 1.0
# draws =  0.1 0.6 0.0 0.0
# 119 Fraction of wins =  0.6 Fraction of draws =  0.1
# 119 alpha =  0.0005403600876626365 epsilon =  0.18912603068192277
# wins =  0.9 0.3 0.1 0.9
# draws =  0.1 0.5 0.1 0.0
# 129 Fraction of wins =  0.6 Fraction of draws =  0.0
# 129 alpha =  0.0005133420832795047 epsilon =  0.1796697291478266
# wins =  0.8 0.2 0.0 1.0
# draws =  0.2 0.6 0.1 0.0
# 139 Fraction of wins =  0.7 Fraction of draws =  0.0
# 139 alpha =  0.00048767497911552944 epsilon =  0.17068624269043528
# wins =  0.9 0.4 0.1 0.9
# draws =  0.1 0.2 0.4 0.0
# 149 Fraction of wins =  0.3 Fraction of draws =  0.1
# 149 alpha =  0.00046329123015975297 epsilon =  0.1621519305559135
# wins =  0.7 0.3 0.0 1.0
# draws =  0.2 0.6 0.0 0.0
# 150
# 159 Fraction of wins =  0.8 Fraction of draws =  0.0
# 159 alpha =  0.0004401266686517653 epsilon =  0.15404433402811782
# wins =  1.0 0.3 0.1 1.0
# draws =  0.0 0.2 0.1 0.0
# 169 Fraction of wins =  0.8 Fraction of draws =  0.1
# 169 alpha =  0.00041812033521917703 epsilon =  0.14634211732671193
# wins =  0.8 0.4 0.2 0.9
# draws =  0.0 0.3 0.1 0.0
# 179 Fraction of wins =  0.9 Fraction of draws =  0.0
# 179 alpha =  0.00039721431845821814 epsilon =  0.13902501146037632
# wins =  0.9 0.9 0.3 1.0
# draws =  0.0 0.1 0.1 0.0
# 189 Fraction of wins =  0.5 Fraction of draws =  0.0
# 189 alpha =  0.0003773536025353072 epsilon =  0.1320737608873575
# wins =  0.9 0.5 0.0 1.0
# draws =  0.1 0.3 0.3 0.0
# 199 Fraction of wins =  0.4 Fraction of draws =  0.1
# 199 alpha =  0.0003584859224085418 epsilon =  0.1254700728429896
# wins =  0.9 0.5 0.0 1.0
# draws =  0.1 0.4 0.4 0.0
# 200
# 209 Fraction of wins =  1.0 Fraction of draws =  0.0
# 209 alpha =  0.0003405616262881147 epsilon =  0.11919656920084012
# wins =  1.0 0.4 0.2 1.0
# draws =  0.0 0.3 0.4 0.0
# 219 Fraction of wins =  0.6 Fraction of draws =  0.0
# 219 alpha =  0.00032353354497370894 epsilon =  0.11323674074079812
# wins =  0.9 0.6 0.0 1.0
# draws =  0.0 0.3 0.2 0.0
# 229 Fraction of wins =  0.5 Fraction of draws =  0.1
# 229 alpha =  0.00030735686772502346 epsilon =  0.1075749037037582
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.0 0.4 0.0
# 239 Fraction of wins =  0.7 Fraction of draws =  0.0
# 239 alpha =  0.00029198902433877225 epsilon =  0.1021961585185703
# wins =  0.9 0.5 0.0 1.0
# draws =  0.1 0.3 0.4 0.0
# 249 Fraction of wins =  0.7 Fraction of draws =  0.1
# 249 alpha =  0.00027738957312183364 epsilon =  0.09708635059264177
# wins =  1.0 0.3 0.2 1.0
# draws =  0.0 0.3 0.2 0.0
# 250
# 259 Fraction of wins =  0.7 Fraction of draws =  0.0
# 259 alpha =  0.0002635200944657419 epsilon =  0.09223203306300967
# wins =  0.7 0.7 0.0 0.9
# draws =  0.3 0.2 0.3 0.0
# 269 Fraction of wins =  0.8 Fraction of draws =  0.0
# 269 alpha =  0.0002503440897424548 epsilon =  0.08762043140985919
# wins =  1.0 0.5 0.1 1.0
# draws =  0.0 0.3 0.1 0.0
# 279 Fraction of wins =  0.7 Fraction of draws =  0.1
# 279 alpha =  0.00023782688525533205 epsilon =  0.08323940983936623
# wins =  0.9 0.5 0.1 1.0
# draws =  0.1 0.1 0.3 0.0
# 289 Fraction of wins =  0.8 Fraction of draws =  0.0
# 289 alpha =  0.00022593554099256544 epsilon =  0.07907743934739792
# wins =  0.9 0.5 0.2 0.9
# draws =  0.1 0.2 0.1 0.0
# 299 Fraction of wins =  0.8 Fraction of draws =  0.0
# 299 alpha =  0.00021463876394293716 epsilon =  0.07512356738002801
# wins =  1.0 0.4 0.1 1.0
# draws =  0.0 0.3 0.3 0.0
# 300
# 309 Fraction of wins =  0.8 Fraction of draws =  0.0
# 309 alpha =  0.0002039068257457903 epsilon =  0.07136738901102661
# wins =  1.0 0.8 0.3 0.9
# draws =  0.0 0.0 0.1 0.0
# 319 Fraction of wins =  0.7 Fraction of draws =  0.0
# 319 alpha =  0.00019371148445850077 epsilon =  0.06779901956047528
# wins =  1.0 0.7 0.2 0.9
# draws =  0.0 0.2 0.0 0.0
# 329 Fraction of wins =  0.8 Fraction of draws =  0.0
# 329 alpha =  0.00018402591023557573 epsilon =  0.06440906858245152
# wins =  1.0 0.9 0.1 1.0
# draws =  0.0 0.1 0.0 0.0
# 339 Fraction of wins =  0.9 Fraction of draws =  0.0
# 339 alpha =  0.00017482461472379692 epsilon =  0.06118861515332894
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.0 0.2 0.0
# 349 Fraction of wins =  0.7 Fraction of draws =  0.0
# 349 alpha =  0.00016608338398760707 epsilon =  0.05812918439566249
# wins =  0.8 0.7 0.2 1.0
# draws =  0.0 0.0 0.1 0.0
# 350
# 359 Fraction of wins =  0.2 Fraction of draws =  0.0
# 359 alpha =  0.0001577792147882267 epsilon =  0.05522272517587936
# wins =  0.9 0.6 0.0 0.9
# draws =  0.1 0.0 0.3 0.0
# 369 Fraction of wins =  0.8 Fraction of draws =  0.0
# 369 alpha =  0.00014989025404881537 epsilon =  0.05246158891708539
# wins =  1.0 0.8 0.3 1.0
# draws =  0.0 0.1 0.0 0.0
# 379 Fraction of wins =  0.8 Fraction of draws =  0.0
# 379 alpha =  0.00014239574134637458 epsilon =  0.05
# wins =  1.0 0.8 0.2 1.0
# draws =  0.0 0.1 0.1 0.0
# 389 Fraction of wins =  0.6 Fraction of draws =  0.0
# 389 alpha =  0.00013527595427905584 epsilon =  0.05
# wins =  1.0 0.6 0.3 1.0
# draws =  0.0 0.1 0.1 0.0
# 399 Fraction of wins =  0.5 Fraction of draws =  0.0
# 399 alpha =  0.00012851215656510304 epsilon =  0.05
# wins =  1.0 0.6 0.1 1.0
# draws =  0.0 0.1 0.1 0.0
# 400
# 409 Fraction of wins =  0.7 Fraction of draws =  0.0
# 409 alpha =  0.00012208654873684788 epsilon =  0.05
# wins =  1.0 0.8 0.2 1.0
# draws =  0.0 0.1 0.3 0.0
# 419 Fraction of wins =  0.8 Fraction of draws =  0.0
# 419 alpha =  0.00011598222130000548 epsilon =  0.05
# wins =  0.9 0.6 0.1 0.9
# draws =  0.0 0.1 0.1 0.0
# 429 Fraction of wins =  0.6 Fraction of draws =  0.0
# 429 alpha =  0.00011018311023500519 epsilon =  0.05
# wins =  1.0 0.7 0.0 1.0
# draws =  0.0 0.0 0.0 0.0
# 439 Fraction of wins =  0.7 Fraction of draws =  0.0
# 439 alpha =  0.00010467395472325493 epsilon =  0.05
# wins =  1.0 0.7 0.0 1.0
# draws =  0.0 0.0 0.3 0.0
# 449 Fraction of wins =  0.8 Fraction of draws =  0.0
# 449 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.0 1.0
# draws =  0.0 0.1 0.0 0.0
# 450
# 459 Fraction of wins =  0.9 Fraction of draws =  0.0
# 459 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.1 0.1 0.0
# 469 Fraction of wins =  0.9 Fraction of draws =  0.0
# 469 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.9 0.1 0.9
# draws =  0.0 0.0 0.0 0.0
# 479 Fraction of wins =  0.8 Fraction of draws =  0.0
# 479 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.5 0.1 1.0
# draws =  0.0 0.2 0.2 0.0
# 489 Fraction of wins =  0.9 Fraction of draws =  0.0
# 489 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.4 0.0 0.9
# draws =  0.0 0.2 0.0 0.0
# 499 Fraction of wins =  0.6 Fraction of draws =  0.1
# 499 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.2 0.3 0.0
# 500
# 509 Fraction of wins =  0.7 Fraction of draws =  0.0
# 509 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.2 1.0
# draws =  0.0 0.0 0.5 0.0
# 519 Fraction of wins =  0.6 Fraction of draws =  0.0
# 519 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.1 0.3 0.0
# 529 Fraction of wins =  1.0 Fraction of draws =  0.0
# 529 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 0.9
# draws =  0.0 0.2 0.3 0.0
# 539 Fraction of wins =  0.5 Fraction of draws =  0.0
# 539 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.2 1.0
# draws =  0.0 0.1 0.2 0.0
# 549 Fraction of wins =  0.8 Fraction of draws =  0.0
# 549 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.2 1.0
# draws =  0.0 0.2 0.3 0.0
# 550
# 559 Fraction of wins =  0.5 Fraction of draws =  0.0
# 559 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.0 0.2 0.0
# 569 Fraction of wins =  0.5 Fraction of draws =  0.0
# 569 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.1 0.2 0.0
# 579 Fraction of wins =  0.8 Fraction of draws =  0.0
# 579 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.7 0.1 0.9
# draws =  0.0 0.0 0.1 0.0
# 589 Fraction of wins =  0.9 Fraction of draws =  0.0
# 589 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.2 1.0
# draws =  0.0 0.2 0.2 0.0
# 599 Fraction of wins =  0.6 Fraction of draws =  0.0
# 599 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.4 0.1 1.0
# draws =  0.0 0.3 0.2 0.0
# 600
# 609 Fraction of wins =  0.9 Fraction of draws =  0.0
# 609 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.0 0.2 0.0
# 619 Fraction of wins =  0.4 Fraction of draws =  0.0
# 619 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.0 0.0 0.0
# 629 Fraction of wins =  0.5 Fraction of draws =  0.0
# 629 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.2 0.9
# draws =  0.0 0.3 0.1 0.0
# 639 Fraction of wins =  0.4 Fraction of draws =  0.1
# 639 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.0 1.0
# draws =  0.0 0.2 0.0 0.0
# 649 Fraction of wins =  0.5 Fraction of draws =  0.0
# 649 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.0 1.0
# draws =  0.0 0.2 0.2 0.0
# 650
# 659 Fraction of wins =  0.8 Fraction of draws =  0.0
# 659 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.8 0.0 1.0
# draws =  0.0 0.2 0.2 0.0
# 669 Fraction of wins =  0.5 Fraction of draws =  0.0
# 669 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.1 0.2 0.0
# 679 Fraction of wins =  0.7 Fraction of draws =  0.0
# 679 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.0 0.9
# draws =  0.0 0.1 0.2 0.0
# 689 Fraction of wins =  0.7 Fraction of draws =  0.0
# 689 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.9 0.2 1.0
# draws =  0.0 0.1 0.0 0.0
# 699 Fraction of wins =  0.6 Fraction of draws =  0.0
# 699 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.1 0.9
# draws =  0.0 0.1 0.2 0.0
# 700
# 709 Fraction of wins =  0.8 Fraction of draws =  0.0
# 709 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.0 0.9
# draws =  0.0 0.0 0.1 0.0
# 719 Fraction of wins =  0.5 Fraction of draws =  0.0
# 719 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.0 1.0
# draws =  0.0 0.1 0.0 0.0
# 729 Fraction of wins =  0.8 Fraction of draws =  0.0
# 729 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.6 0.1 1.0
# draws =  0.1 0.1 0.1 0.0
# 739 Fraction of wins =  0.5 Fraction of draws =  0.0
# 739 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.8 0.0 1.0
# draws =  0.0 0.0 0.2 0.0
# 749 Fraction of wins =  0.5 Fraction of draws =  0.0
# 749 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 0.9
# draws =  0.0 0.2 0.4 0.0
# 750
# 759 Fraction of wins =  0.8 Fraction of draws =  0.0
# 759 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.1 1.0
# draws =  0.0 0.1 0.0 0.0
# 769 Fraction of wins =  0.6 Fraction of draws =  0.0
# 769 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.8 0.0 1.0
# draws =  0.0 0.1 0.1 0.0
# 779 Fraction of wins =  0.7 Fraction of draws =  0.0
# 779 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.1 1.0
# draws =  0.0 0.1 0.3 0.0
# 789 Fraction of wins =  0.8 Fraction of draws =  0.0
# 789 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.7 0.2 0.9
# draws =  0.1 0.2 0.1 0.0
# 799 Fraction of wins =  0.9 Fraction of draws =  0.0
# 799 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.8 0.2 1.0
# draws =  0.0 0.1 0.1 0.0
# 800
# 809 Fraction of wins =  0.8 Fraction of draws =  0.0
# 809 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.6 0.1 1.0
# draws =  0.0 0.1 0.1 0.0
# 819 Fraction of wins =  0.9 Fraction of draws =  0.1
# 819 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.2 1.0
# draws =  0.0 0.1 0.1 0.0
# 829 Fraction of wins =  0.8 Fraction of draws =  0.0
# 829 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.2 1.0
# draws =  0.0 0.1 0.1 0.0
# 839 Fraction of wins =  0.7 Fraction of draws =  0.0
# 839 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.0 0.9
# draws =  0.0 0.0 0.1 0.0
# 849 Fraction of wins =  0.6 Fraction of draws =  0.0
# 849 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.6 0.1 1.0
# draws =  0.0 0.1 0.4 0.0
# 850
# 859 Fraction of wins =  0.7 Fraction of draws =  0.1
# 859 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.3 1.0
# draws =  0.0 0.0 0.2 0.0
# 869 Fraction of wins =  0.6 Fraction of draws =  0.0
# 869 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 1.0
# draws =  0.0 0.1 0.4 0.0
# 879 Fraction of wins =  0.9 Fraction of draws =  0.0
# 879 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.1 1.0
# draws =  0.0 0.3 0.1 0.0
# 889 Fraction of wins =  0.8 Fraction of draws =  0.0
# 889 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.0 0.8
# draws =  0.0 0.3 0.0 0.0
# 899 Fraction of wins =  0.8 Fraction of draws =  0.0
# 899 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.2 0.9
# draws =  0.0 0.3 0.0 0.0
# 900
# 909 Fraction of wins =  0.6 Fraction of draws =  0.0
# 909 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.5 0.1 1.0
# draws =  0.0 0.3 0.1 0.0
# 919 Fraction of wins =  0.7 Fraction of draws =  0.0
# 919 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.2 0.8
# draws =  0.0 0.0 0.1 0.0
# 929 Fraction of wins =  0.6 Fraction of draws =  0.0
# 929 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.6 0.1 1.0
# draws =  0.0 0.1 0.1 0.0
# 939 Fraction of wins =  0.9 Fraction of draws =  0.0
# 939 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.9 0.1 1.0
# draws =  0.0 0.0 0.4 0.0
# 949 Fraction of wins =  0.6 Fraction of draws =  0.0
# 949 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.1 0.9
# draws =  0.0 0.1 0.0 0.0
# 950
# 959 Fraction of wins =  0.9 Fraction of draws =  0.0
# 959 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.3 1.0
# draws =  0.0 0.1 0.1 0.0
# 969 Fraction of wins =  0.7 Fraction of draws =  0.0
# 969 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.8 0.2 1.0
# draws =  0.0 0.1 0.1 0.0
# 979 Fraction of wins =  0.6 Fraction of draws =  0.0
# 979 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 0.7 0.0 0.9
# draws =  0.0 0.1 0.1 0.0
# 989 Fraction of wins =  0.7 Fraction of draws =  0.0
# 989 alpha =  0.0001 epsilon =  0.05
# wins =  0.9 0.7 0.0 1.0
# draws =  0.1 0.1 0.2 0.0
# 999 Fraction of wins =  0.5 Fraction of draws =  0.0
# 999 alpha =  0.0001 epsilon =  0.05
# wins =  1.0 1.0 0.1 1.0
# draws =  0.0 0.0 0.1 0.0

# %%
data = {'all_results':all_results,
        'all_draws':all_draws,
        'all_oppn_idx':all_oppn_idx,
        'all_weights':all_weights,
        'all_num':all_num,
        'all_rewards':all_rewards,
        'test_results_rand':test_results_rand,
        'test_results_1':test_results_1,
        'test_results_2':test_results_2,
        'test_results_3':test_results_3,
        'test_draws_rand':test_draws_rand,
        'test_draws_1':test_draws_1,
        'test_draws_2':test_draws_2,
        'test_draws_3':test_draws_3}
with open(r"SARSA_33_features_checker_reward_mix_oppn_reverse_rule_at_1000_manual_tuning_alpha_eps.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
all_weights_array = np.stack(all_weights)
np.squeeze(all_weights_array).shape
plt.plot(np.squeeze(all_weights_array));

# %%
loss_rand = 1-np.array(test_results_rand)-np.array(test_draws_rand)
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_results_rand,label='win'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_draws_rand,label='draw'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),loss_rand,label='loss')
plt.legend()
plt.xlabel('Number of training games')
plt.ylabel('Fraction of test games')
plt.title('Test results against random agent');

# %%
loss_1 = 1-np.array(test_results_1)-np.array(test_draws_1)
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_results_1,label='win'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_draws_1,label='draw'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),loss_1,label='loss')
plt.legend()
plt.xlabel('Number of training games')
plt.ylabel('Fraction of test games')
plt.title('Test results against AB(1)');

# %%
loss_2 = 1-np.array(test_results_2)-np.array(test_draws_2)
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_results_2,label='win'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_draws_2,label='draw'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),loss_2,label='loss')
plt.legend()
plt.xlabel('Number of training games')
plt.ylabel('Fraction of test games')
plt.title('Test results against AB(2)');

# %%
loss_3 = 1-np.array(test_results_3)-np.array(test_draws_3)
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_results_3,label='win'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),test_draws_3,label='draw'),
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),loss_3,label='loss')
plt.legend()
plt.xlabel('Number of training games')
plt.ylabel('Fraction of test games')
plt.title('Test results against AB(3)');

# %%
w = 50
calib = np.convolve(np.ones(n_train_games+n_train_games_post_reversal), np.ones(w), 'same')
all_score = 1*np.array(all_results) + 0.5*np.array(all_draws)
mean_smooth_score = np.convolve(all_score, np.ones(w), 'same') / calib
plt.plot(mean_smooth_score)
plt.xlabel('# of training games')
plt.ylabel('Smoothed score');

# %%
w = 10
calib = np.convolve(np.ones(len(test_results_rand)), np.ones(w), 'same')
all_score_rand = 1*np.array(test_results_rand) + 0.5*np.array(test_draws_rand)
all_score_1 = 1*np.array(test_results_1) + 0.5*np.array(test_draws_1)
all_score_2 = 1*np.array(test_results_2) + 0.5*np.array(test_draws_2)
all_score_3 = 1*np.array(test_results_3) + 0.5*np.array(test_draws_3)
mean_smooth_score_rand = np.convolve(all_score_rand, np.ones(w), 'same') / calib
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),mean_smooth_score_rand, label='Rand')
mean_smooth_score_1 = np.convolve(all_score_1, np.ones(w), 'same') / calib
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),mean_smooth_score_1, label='AB1')
mean_smooth_score_2 = np.convolve(all_score_2, np.ones(w), 'same') / calib
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),mean_smooth_score_2,label='AB2')
mean_smooth_score_3 = np.convolve(all_score_3, np.ones(w), 'same') / calib
plt.plot(np.arange(0,n_train_games+n_train_games_post_reversal+1,test_frequency),mean_smooth_score_3,label='AB3')
plt.legend(bbox_to_anchor=(1,1.02))
plt.xlabel('# of training games')
plt.ylabel('Smoothed score');
